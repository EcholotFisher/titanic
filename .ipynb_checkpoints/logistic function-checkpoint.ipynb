# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
plt.style.use('seaborn')

# %%
def logistic(t):
    return 1/(1+np.exp(-t))

# %%
np.arange(-10,10,0.1)
# Out:
# array([-1.00000000e+01, -9.90000000e+00, -9.80000000e+00, -9.70000000e+00,
#        -9.60000000e+00, -9.50000000e+00, -9.40000000e+00, -9.30000000e+00,
#        -9.20000000e+00, -9.10000000e+00, -9.00000000e+00, -8.90000000e+00,
#        -8.80000000e+00, -8.70000000e+00, -8.60000000e+00, -8.50000000e+00,
#        -8.40000000e+00, -8.30000000e+00, -8.20000000e+00, -8.10000000e+00,
#        -8.00000000e+00, -7.90000000e+00, -7.80000000e+00, -7.70000000e+00,
#        -7.60000000e+00, -7.50000000e+00, -7.40000000e+00, -7.30000000e+00,
#        -7.20000000e+00, -7.10000000e+00, -7.00000000e+00, -6.90000000e+00,
#        -6.80000000e+00, -6.70000000e+00, -6.60000000e+00, -6.50000000e+00,
#        -6.40000000e+00, -6.30000000e+00, -6.20000000e+00, -6.10000000e+00,
#        -6.00000000e+00, -5.90000000e+00, -5.80000000e+00, -5.70000000e+00,
#        -5.60000000e+00, -5.50000000e+00, -5.40000000e+00, -5.30000000e+00,
# ...

# %%
z = np.arange(-5,5,0.1)
sigma_t = [a for a in map(logistic,z)]



fig, ax = plt.subplots()
plt.plot(z,sigma_t)
plt.plot(z,np.repeat(0.5,len(z)),linestyle=':',color='black')
plt.plot(z,np.repeat(1,len(z)),linestyle=':',color='black')
plt.axvline(0,linestyle='-',color='black',ylabel='test')
#plt.ylabel('$\sigma(t)$')
plt.xlabel('t')
# Out:
# <div id='9e475afa-1c04-4955-b96f-b5105a8c91d9'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-6bdf67e324d5> in <module>
#       8 plt.plot(z,np.repeat(0.5,len(z)),linestyle=':',color='black')
#       9 plt.plot(z,np.repeat(1,len(z)),linestyle=':',color='black')
# ---> 10 plt.axvline(0,linestyle='-',color='black',ylabel='test')
#      11 #plt.ylabel('$\sigma(t)$')
#      12 plt.xlabel('t')
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in axvline(x, ymin, ymax, **kwargs)
#    2422 @docstring.copy(Axes.axvline)
#    2423 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# -> 2424     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#    2425
#    2426
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in axvline(self, x, ymin, ymax, **kwargs)
#     932
# ...

# %%
fig, (ax1,ax2) = plt.subplots(2,1)
ax1.plot(sigma_t,-np.log(sigma_t))
ax1.set_ylabel('$-log(\hat{p})$')
ax1.set_title('y=1')

ax2.plot(sigma_t,-np.log([1-a for a in sigma_t]))
ax2.set_ylabel('$-log((1-\hat{p}))$')
ax2.set_title('y=0')
ax2.set_xlabel('$\hat{p}$')
fig.suptitle('Loss as a function of estimated probability')
#ax1.xlabel('$\hat{p}$')
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# Text(0.5, 0.98, 'Loss as a function of estimated probability')

# %%
# Out:
# Text(0.5, 71.48889104525244, '$\\hat{p}$')
